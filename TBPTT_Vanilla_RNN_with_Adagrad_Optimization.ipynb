# %%
"""
Refactored Minimal Character-Level Vanilla RNN.
Original Author: Andrej Karpathy (@karpathy)
License: BSD

Modified By: Kirubel Awoke, aka,light337
"""
import numpy as np
import sys

# --- I/O and Data Preprocessing ---

# Ensure compatibility with file opening across environments
try:
    with open('pride_and_prejudice.txt', 'r', encoding='utf-8') as f:
        data = f.read()
except FileNotFoundError:
    print("Error: 'input.txt' not found. Please provide a training corpus.")
    sys.exit(1)

chars = list(set(data))
data_size, vocab_size = len(data), len(chars)

# FIX: Python 2 'print' statement converted to Python 3 'print()' function
print('data has %d characters, %d unique.' % (data_size, vocab_size))

# Mappings
char_to_ix = { ch:i for i,ch in enumerate(chars) }
ix_to_char = { i:ch for i,ch in enumerate(chars) }

# --- Hyperparameters and Model Initialization ---

# Hyperparameters
HIDDEN_SIZE = 100    # Size of hidden layer of neurons (H)
SEQ_LENGTH = 25      # Steps to unroll the RNN (T)
LEARNING_RATE = 1e-1 # Adagrad learning rate

# Model Parameters (Matrices and Biases)
# Weight initialization: small random numbers (~0.01) to prevent saturation
Wxh = np.random.randn(HIDDEN_SIZE, vocab_size) * 0.01  # Input-to-Hidden (H x V)
Whh = np.random.randn(HIDDEN_SIZE, HIDDEN_SIZE) * 0.01 # Hidden-to-Hidden (H x H)
Why = np.random.randn(vocab_size, HIDDEN_SIZE) * 0.01  # Hidden-to-Output (V x H)
bh = np.zeros((HIDDEN_SIZE, 1))                        # Hidden Bias (H x 1)
by = np.zeros((vocab_size, 1))                         # Output Bias (V x 1)

# --- Core Functions: Loss/Grad and Sampling ---

def loss_fun(inputs, targets, hprev):
    """
    Computes the loss and gradients for one sequence of data.
    inputs, targets are lists of integer indices.
    hprev is the Hx1 array of initial hidden state.
    Returns: loss, gradients (dWxh, dWhh, dWhy, dbh, dby), and last hidden state.
    """
    xs, hs, ys, ps = {}, {}, {}, {}
    hs[-1] = np.copy(hprev)
    loss = 0

    # 1. Forward Pass (Sequence Iteration)
    # FIX: Python 2 'xrange' replaced with Python 3 'range'
    for t in range(len(inputs)):
        # One-hot encoding of input x[t]
        xs[t] = np.zeros((vocab_size,1))
        xs[t][inputs[t]] = 1

        # RNN Update Equations (Hidden state and Output score)
        hs[t] = np.tanh(np.dot(Wxh, xs[t]) + np.dot(Whh, hs[t-1]) + bh) # h[t]
        ys[t] = np.dot(Why, hs[t]) + by                                # y[t] (unnormalized log-probs)

        # Softmax: convert scores to probabilities p[t]
        # Robust Softmax (Optional, but good practice): p = np.exp(y - np.max(y)) / np.sum(np.exp(y - np.max(y)))
        ps[t] = np.exp(ys[t]) / np.sum(np.exp(ys[t]))

        # Cross-Entropy Loss: L = -log(P(target))
        loss += -np.log(ps[t][targets[t],0])

    # 2. Backward Pass (Backpropagation Through Time, BPTT)
    dWxh, dWhh, dWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
    dbh, dby = np.zeros_like(bh), np.zeros_like(by)
    dhnext = np.zeros_like(hs[0])

    # FIX: Python 2 'xrange' replaced with Python 3 'range'
    for t in reversed(range(len(inputs))):
        # Backprop through Softmax/Loss
        dy = np.copy(ps[t])
        dy[targets[t]] -= 1 # The gradient of the loss w.r.t the unnormalized log-probabilities y[t]

        # Backprop through Output layer (Why, by)
        dWhy += np.dot(dy, hs[t].T)
        dby += dy

        # Backprop through Hidden state h[t] and Recurrence
        dh = np.dot(Why.T, dy) + dhnext
        dhraw = (1 - hs[t] * hs[t]) * dh # Backprop through tanh nonlinearity: d(tanh(x))/dx = 1 - tanh^2(x)

        # Backprop through Hidden layer (Wxh, Whh, bh)
        dbh += dhraw
        dWxh += np.dot(dhraw, xs[t].T)
        dWhh += np.dot(dhraw, hs[t-1].T)

        # Pass gradient to previous time step
        dhnext = np.dot(Whh.T , dhraw)

    # Gradient Clipping: Mitigate Exploding Gradients (L2 norm clipping is better, but this is simple)
    for dparam in [dWxh, dWhh, dWhy, dbh, dby]:
        np.clip(dparam, -5, 5, out=dparam)

    return loss, dWxh, dWhh, dWhy, dbh, dby, hs[len(inputs)-1]

def sample(h, seed_ix, n_steps):
    """
    Samples a sequence of n_steps from the model, starting with seed_ix.
    h is the initial hidden state.
    """
    x = np.zeros((vocab_size, 1))
    x[seed_ix] = 1
    ixes = []

    # FIX: Python 2 'xrange' replaced with Python 3 'range'
    for _ in range(n_steps):
        # Forward pass (Inference)
        h = np.tanh(np.dot(Wxh, x) + np.dot(Whh, h) + bh)
        y = np.dot(Why, h) + by
        p = np.exp(y) / np.sum(np.exp(y))

        # Stochastic Sampling: Select next character index based on probability distribution p
        ix = np.random.choice(range(vocab_size), p=p.ravel())

        # Prepare next input (one-hot vector for the sampled index)
        x = np.zeros((vocab_size, 1))
        x[ix] = 1
        ixes.append(ix)

    return ixes

# --- Training Loop and Adagrad Optimization ---

n, p = 0, 0
# Memory variables for Adagrad optimizer
mWxh, mWhh, mWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
mbh, mby = np.zeros_like(bh), np.zeros_like(by)
# Initialize loss (Perplexity P = vocab_size)
smooth_loss = -np.log(1.0/vocab_size) * SEQ_LENGTH

# The Main Training Loop
while True:
    # Set RNN memory and data pointer (reset every epoch or at start)
    if p + SEQ_LENGTH + 1 >= len(data) or n == 0:
        hprev = np.zeros((HIDDEN_SIZE,1)) # Reset RNN memory
        p = 0 # Go from start of data

    # Prepare sequence batch (inputs and one-step-ahead targets)
    inputs = [char_to_ix[ch] for ch in data[p:p+SEQ_LENGTH]]
    targets = [char_to_ix[ch] for ch in data[p+1:p+SEQ_LENGTH+1]]

    # Sample and print progress every 100 iterations
    if n % 100 == 0:
        sample_ix = sample(hprev, inputs[0], 200)
        txt = ''.join(ix_to_char[ix] for ix in sample_ix)
        # FIX: Python 2 'print' statement converted to Python 3 'print()' function
        print('----\n %s \n----' % (txt, ))

    # Forward/Backward pass
    loss, dWxh, dWhh, dWhy, dbh, dby, hprev = loss_fun(inputs, targets, hprev)

    # Exponentially smoothed loss (for stable tracking)
    smooth_loss = smooth_loss * 0.999 + loss * 0.001

    if n % 100 == 0:
        # FIX: Python 2 'print' statement converted to Python 3 'print()' function
        print('iter %d, loss: %f' % (n, smooth_loss))

    # Adagrad Update: Efficient, adaptive learning rate optimization
    for param, dparam, mem in zip([Wxh, Whh, Why, bh, by],
                                  [dWxh, dWhh, dWhy, dbh, dby],
                                  [mWxh, mWhh, mWhy, mbh, mby]):
        mem += dparam * dparam
        # Update rule: W = W - LR * dW / sqrt(mem + epsilon)
        param += -LEARNING_RATE * dparam / (np.sqrt(mem) + 1e-8)

    # Advance data pointer and iteration counter
    p += SEQ_LENGTH
    n += 1
# Out:
# Streaming output truncated to the last 5000 lines.
# if with his and
# mantle’s greated she were courten in repabstitt. DI I mother of the reaching
# Projech,--                     56?
# Col ingle, happy, and Project betweld; ands
# ----
# iter 2813700, loss: 41.593893
# ----
#
# sirt Mr. Darcy has opening I no senle of that impossible their expect her till like the on the ruclods agciet
# detcangial yatter abosed these sucedfbally _me.” spetably a so eur, so know Elizabeth wil
# ----
# iter 2813800, loss: 41.565933
# ----
#  ke long han_ whunsing of proper you freation withoolly not of Lond_ Elizabeth of it, to Charlown, copily so him. As that in Lozzmofity, and ceer the
# spoke the mother hunjussely been,
# in hemaing with h
# ----
# iter 2813900, loss: 41.643198
# ----
#   of much she is part crions, and flotsing equal--to Mr. Darcy--sis.”
#
# “Lady
# Catherine impless of sister surpricity generfur a visis we Jane for changibe.”
#
# She looked herselress muspeady the as were c
# ----
# iter 2814000, loss: 41.613513
# ----
#                                                                                                       26 Cvabter a letter on the seem of insule could not in she there
# genoussed word the ture, is may se
# ----
# iter 2814100, loss: 40.822834
# ----
#                         --]]
#
# Has, that I her
# great of summis, in such a such _they fordile, and
# [_Copyot for to I
# may rather my _there nevesion working
# ofeat Cal o
# ----
# iter 2814200, loss: 38.767362
# ----
#                     2842
# THAS
# 1.7 CHABENY GUow Gurlight it prejust sistan so very agay a with engage it could sister, who sicudable solitegred Kitty all deen, were suld _ackent, and the ratlan of So wo
# ----
# iter 2814300, loss: 36.798232
# ----
#  concerning of it was as Stronces as plaration
# of our for bet ingance well not Staten. wh cansol pay did nor to Suet extriest a comoncerhaffion and her is excention on Lady Cathert reprofosed secren an
# ----
# iter 2814400, loss: 35.774724
# ----
#   of be charar ination lemition, all the expently anore and nothing pleasing, I have
# Sir William on ind. But
# is a grome for wight perseation. I ill-yourself were (and the underait mantres deary, servat
# ----
# iter 2814500, loss: 35.870918
# ----
#  nt, as muspeaved, I have Chas to Nemongry in one,
# you; and
# meminessting only regred of the his effectly rather morty.”
#
# “And
# a come and a felt when that fastog-_els,” can
# more no
# generatest the hear b
# ----
# iter 2814600, loss: 35.859268
# ----
#  very,
# them visit hands
# and itting what nor would great heard of thew light.
#
# But must walk she would not an it,
# in clartanly) will mis_ little something ampise after marry, is, Jane such an only prong
# ----
# iter 2814700, loss: 35.879407
# ----
#  yundins as the Pemuter, all the uncle very receesmonce, a
# day, and whethersely, of what it.
#
# 1 drojuscent he, rejoiced, “Altable her no child; and by famer all not in
# , wook.”
#
# “But when tempare smile
# ----
# iter 2814800, loss: 35.769341
# ----
#  ommonnoted refuncences_ the
# proper,
# wh the and, manner the offere he happeal could not a such; expections
# has
# estivally have conds. That to her set slaughter a not in Miss Austended Miss you note to _
# ----
# iter 2814900, loss: 35.589291
# ----
#   drearly of her the ong suced affect ons it see her vanged it”
#
# “Shyrust almush lectoor to speaken condech an me comen and samituent, after consiquepon there paysisht conjleithoobsing too trouss,
# the
# ----
# iter 2815000, loss: 35.430256
# ----
#  s that I do merely; are lover his intent sorting with as some admish to the offech his fine doraby him will no you their by be,
# with guintss and wheching I contended persible had Sthy project only gro
# ----
# iter 2815100, loss: 35.480603
# ----
#  r you to the nothings.”
#
# “Git to destentioded is give statled had she will neither very father gred. Ruslar Bingley. Thing,
# for may there or creen childhes. Moly letter.”
#
# “I even of sinering his day
# ----
# iter 2815200, loss: 35.446357
# ----
#  ing manner. The spoke from Cand
# disadomparilisharate wide the dance two with the consequepted, their find of yway of her enoral had entions could reass A consire
# sort
# was “Yeilaciou wat discover. She
# ----
# iter 2815300, loss: 35.515896
# ----
#  se away, said say what were only unaul, will strengly than not immediarer morta they them childry to from does
# life exque to delfbar impranes and has become, sifule_ agreren to with theich sorrialing
# ----
# iter 2815400, loss: 35.508252
# ----
#   their, and that he as up Nethan when some takked to happished cousinst. Mrs. Bennet, “Bindured Mrese was are.”
#
# “Asiolle. Miss Bingley; that nene
# admile by sonters inly
# fording he remarkabler pown, a
# ----
# iter 2815500, loss: 35.490030
# ----
#  e he which they spits, she, it was XXXII.    Mrsanes, would look obseny a worlly diserved there; and I art the say.
#
# _Ther
# is it, gives sud. Colosely at are evolfly will be
# youngs or petelving, of per
# ----
# iter 2815600, loss: 35.444448
# ----
#  eed happy
# to be speaking prefortabferes, Mrs. Ganded, derver excited accorce door kind to its have assice; in Elizabeth; “your goloty_.
#
# “I have room Bingley, tooked belucaloonding trelving morey to y
# ----
# iter 2815700, loss: 35.429701
# ----
#  s exeliess rallentinsity, six felicans be.
# “She was friend it.      Ullextie is to any from I have been meet it. Her
# yourselineace saifer on her better rout their this peroor
# of her faws
# respect
# veryt
# ----
# iter 2815800, loss: 35.418603
# ----
#  e with alserly meter be
# has
# ally dudable’s had should dear and me sisters, and 4
#
# [Illustrose towan mortance such able ask happy lefelation of her.”
#
# “Than they a laugh in frionness; and which
# ----
# iter 2815900, loss: 35.412957
# ----
#  chilt seemed, On
# [Ilsure Elizabeth
# still the of _hacking
# again is
# in partinut, at the should med been
# ablicklet very
# wintiage taken from there.”
#
# “He humous to his
# to compagines. And com
# ----
# iter 2816000, loss: 35.446258
# ----
#  n:
#
# “You
# wontenie, and of his time, its you--were of my you, “I have since when not good Elizabeth dance then were for requirned, of Meryf often were their this parting.”
#
# “And have party would mabley
# ----
# iter 2816100, loss: 35.408939
# ----
#  imserand, tall smish, It say earntiont an all-what I capated and with the
# less blind yew Lizzy, but should effect
# mainer all then she dain him. “Youst. Indwere. Miss  hammed forgeticelce of enturions.
# ----
# iter 2816200, loss: 35.304324
# ----
#  ed with she scaration at refuece of usuling, so ince a lowny of I all own viliney’s disappearer, I dighoril. If I condiciently noth ont
# in repents, **
# “Hundictarmed
# amiabsen
# it out a manner commais,
# ----
# iter 2816300, loss: 35.411351
# ----
#  tion, I an waed for them to han_.”
#
# “He is not dran brother; elcan there who knlwens, and to      be gettenter to leave you is compasye the ont
# manners a worse. “Los_ must a sensinote, were
# compished
# ----
# iter 2816400, loss: 35.439418
# ----
#  rats ofton!” Wky hearing you, I defervacin, excelsed however dack, aftument, towace
# for by their leavediconcerhist shall the stended, was
# at the gire wantirets worked of they ably as with daratie they
# ----
# iter 2816500, loss: 35.475206
# ----
#  he congrided to the nake and us so circuipled they before; and’ecely _was not sulmon’s, “I shapen mish, Lucaser
# prefored may atuly always are walkone will comgrayed by charw od him to the speak of wal
# ----
# iter 2816600, loss: 35.277414
# ----
#  ery farcely therefore, what nothing of to Churssed it.”
#
# “Indeed, in they improce you to Lady Catherine in her shovough were really in
# Mr. Darcy provissiable, and arrant, when noth
# dource her.
#
# Mrs. B
# ----
# iter 2816700, loss: 35.481113
# ----
#  enned is his dinest fentfal should a latt.
# “If -for Mr. Bingley’s she mosory
# were as it agrect in him.”
#
# “My. Ast the hear obsive she is
# a offechtoly, of they may towerness happuntaself of throw lette
# ----
# iter 2816800, loss: 35.438467
# ----
#   condiou, was as where in like the express while. “She loon, at all Whears be rejoyn in on that will neil to yet it.
# Ither the precesing dedult you assupaselations
# any
# or of so. I, as him, always. The
# ----
# iter 2816900, loss: 35.563193
# ----
#  been wonlence eyes. Follour the particerving: by felt are neves _camity. It netteremed hip_
# consish tellgis, and nended their to in to
# Bingley nothing with her tike that lettaching.”
#
# “She in Jane to
# ----
# iter 2817000, loss: 35.642710
# ----
#  ourte.”
#  “Welling again, “that I am speak a genly over insistion,” crist into obsond ot till to stithing
# to discousely with away to stranger doing almost
# tomed, Elizabeth asterstrayed, Bennet of?”
#
# “U
# ----
# iter 2817100, loss: 35.321293
# ----
#  deasing give rust of sisfect-has Profection unsleastent, were dequester speaking surguxsession so dear a longer were so forgivacily uncle.”
#
# “That yourself.”
#
# “Ins anger in befores, to courorioumenned
# ----
# iter 2817200, loss: 35.205725
# ----
#  ister’s over, be wouldether somethonahon, in gourt. Down ought destent
# them.”
# Whill
# to
# purtunners.”
#
# “Yis anythit to bettered the see acamw at a compsiade incous yourthor, “to occeress,
# always sat is
# ----
# iter 2817300, loss: 35.347073
# ----
#  ay short man? He had not arring, from that the more motion acce. Bingley; 1894 ABrelst seeived servould as yon abluth, he quietief day.”
#
# “You dis.”
# Mrs. Fury of loving heren
# espere. Your each the mu
# ----
# iter 2817400, loss: 35.158306
# ----
#  y if a car to you walk a liked before of Mr. Well. She as her awoution. Your--and pleasency by her any procerfisel, she: “time had we then to not in from Mr.
# Darcy out you transoded from frabation tha
# ----
# iter 2817500, loss: 35.264977
# ----
#   the secums seel here entress seembiable whowes predo. Shimed to manned, in her
# knet many which, her added attention had knowed work days to give were Elizabeth. If a sisters; the _here her been were
# ----
# iter 2817600, loss: 35.388482
# ----
#  at sin his amurning taicten they of before is; acknound, with that Myryts a living by the coming neinely
# imaing Bingley,” naired thew--the uttivided blin; and with observed and to the
# iw 18426. Eveope
# ----
# iter 2817700, loss: 35.446342
# ----
#  y the
# extremcits every her. His connert, added
# and becaufe,, and my present excridated which representiritt lady gention feelly
# mudn
# us only nor makebme,
# Preposed at him Colones,”ar way.”
#
# “Miss Eliza
# ----
# iter 2817800, loss: 35.478146
# ----
#   and the expections had been truth thing teater Lady Catling in the oughy; and
# herself; and you can wiffofed overh
# Itherce.”
#
# Jane, Catherst chast agan my
# a, I think be doubme, by your exaltcy, other
# ----
# iter 2817900, loss: 35.596703
# ----
#  h pleadonged shaust you Netently or yee_ing unmery. Mish
# his
# sister
# tos. Milsent very the presention of _head nevere shet so at _was sayim waBubdely word the to be a was a so
#
#
#
# [Illustration]
#
#
#
#
# Mr
# ----
# iter 2818000, loss: 35.491989
# ----
#   But as mose,” railly concern hapul be meanger I_ what within he to their. They delacaped of the Sin--tew the doec with her
# make the dain_ side, indeate whene. They silst. At the myself object though’
# ----
# iter 2818100, loss: 35.578215
# ----
#  ply.
# They the have noth
# been, in diden whith.
#
# They perfury; and you once be
# sistance
# Eliza_--Elizabeth, inchingly; “but her paid Miss Berminal.”
#
# Elizabeth wouldrsing was not muink’s broich gones was
# ----
# iter 2818200, loss: 35.691192
# ----
#  d not previly, if har had keed
# are from them resist of you on Mrs.
# Binglee. While make is are
# up the particularition say rid: expressed into meed.
#
# “Had Elips Mr. Dease inturding-ence
# weld!” and,” con
# ----
# iter 2818300, loss: 35.617504
# ----
#  mmonow,” said I shoperiads ploissing Jane crience to agref chadivelimen at little, was sinting occlive there for his
# would
# laigle, and Bingley told did Darcy. Darcy! The allly to curice,
# silation. The
# ----
# iter 2818400, loss: 35.436956
# ----
#  veryed doubt as on the drearly
# to Net any for when he was
# insiled Amparting joughtle.”
#
# “I tript sid them visite
# to
# compury at tell
# a did doors then let she amovated.”
#
# “Chargeturese her_;
# and I wantu
# ----
# iter 2818500, loss: 35.446012
# ----
#  bted, “she great wordation 8ur. something; their mehimply superionsaged Elizabeth presently pointing ta jistays spoked of him! I
# choon. ANG Lad not subject, and Netherfamine her an in the forcely so f
# ----
# iter 2818600, loss: 35.843329
# ----
#  came, Colless you had suceling your a leustuod, what their to such har
# live with so called, as, _eyest Mark of by mawking
# it seem. He was be eccrefuld relation forded. I reend lady rated the going dis
# ----
# iter 2818700, loss: 36.049162
# ----
#  now compare who little; ande in the _I distoin,
# acknorited you marech; and it _I as to
# be her any intertaning our under, and having daint little, who same almused the affectaving. The faw dust has at
# ----
# iter 2818800, loss: 35.980973
# ----
#  g I ble speak sholp her without, I delight, !                                               4 rearing. He no. What werved in quane thues, and it but you lady any inst chis always though.”
#
# “Oh, that a
# ----
# iter 2818900, loss: 35.928971
# ----
#  lly always a partiousent from,
# and to I am if others, country pooves of and only idlume in intended hanssases of letter quite to make liet feilict himself, and keeppress Mrs. Hupseed, to be; and with
# ----
# iter 2819000, loss: 36.074585
# ----
#  ning you would be in      hope were and him, with begners he wountry looking it were quite; but the genthelded, briady much scare returned pay an want was absualling this in dain imaispled the becomes
# ----
# iter 2819100, loss: 36.236989
# ----
#  ed apel; but much and of she heards or gromance contibuthe and all contisural--e
# expibitily how over,” said she had she by for be pass, in the alsest truthinitude comploom it, nonsing fixhing if alios
# ----
# iter 2819200, loss: 36.292315
# ----
#   all proditiand afteriwafully doonation was,” she is all you is extrances gratibutipe appearath
# about very for impreal wifer a dlact you nothes orgable hill interes to room
# my here his been, it is her
# ----
# iter 2819300, loss: 36.196272
# ----
#   better this unlarioy oppilakes with is made her spos
# utwidguard share denursed, the antund it--do connection room with daffinged were to dear not lady exclied, in the exactuged dispos who my
# Darcy wi
# ----
# iter 2819400, loss: 35.967058
# ----
#  netwedervacon as that      himsead, in greater on the aftent eifed a dimberenced
# in in      now enture family, who is it. He could buss notiotious amovating yever of Me. I haster.
# Lady would have Miss
# ----
# iter 2819500, loss: 35.704785
# ----
#  now, with remacist, after, down, if Jone; She contenue lart, my prepend
# whise on provooble anxaptiraving and word decommagling of that thens,
# “but no
# house, I awatation,
# hours. Height you himself on d
# ----
# iter 2819600, loss: 35.711869
# ----
#  mposucer the friend, never observan. She dain some taicle entirited hes met his
# as I waken, and
# her just see. As the
# still
# intered
# hersand
# you.”
#
# “Had not to my admile. Musane agreeable adort on this
#
# ----
# iter 2819700, loss: 35.583899
# ----
#
# proposames for than the rean ladied one eporise; for yet beinely at Deccsie that yourselve Elizabeth, the begonesced has continuess,
# dain friend. Her all my town, enteren than
# that nitents, as the fi
# ----
# iter 2819800, loss: 35.510886
# ----
#   and
# think seement; abatent
# if I was
# married, and bathe.”
#
# “I keghtes_
# in they. I condicily of upance of My. On Lady
# Cather of sister to juck it is it to a little; “Jane myself of
# ittanly hand with a
# ----
# iter 2819900, loss: 35.757996
# ----
#  ured him; and
# him--sod,
# Bingley to the carried him from a,” returned word, we several conversmonuleasest word her immedion, thround gute, me
# denily,
# waye and letter poins their to cull lady more, his
# ----
# iter 2820000, loss: 35.865268
# ----
#  am a with
# the Darcy
# subject,--
#
# “This
# and
# a conglive, defend new agay how in attending the
# family, “he
# coulse with by her at speak. _Yow a mance many, no
# him, ast could
# not tend expacyed at enderly on
# ----
# iter 2820100, loss: 35.961384
# ----
#  re appeares aporry as Mr. Darcy?”
#
# “You to bemagion Hour
# that some.”
#
# Mr. Bobly them. They of her once wh5 _TMy-day a meands firming more; and not afteression and not temper said I tather her love, to
# ----
# iter 2820200, loss: 35.697155
# ----
#  senching for with offache hardhile, and were the liadratestirg presention of Kittyouss,
# my all soon you tolveace, accude Miss Bynness say were not marrieds;--and fial
# for Mr.
# Wickham,”
# same consapte f
# ----
# iter 2820300, loss: 35.602808
# ----
#  ived tood she was marry inswile such offer of their copy
# griated their at leavely, “I detended but she would nex for uptond but Mr. Bingley; but which well forward to her
# of her
# to Mrs. Bennet was the
# ----
# iter 2820400, loss: 35.392733
# ----
#   not a barthers. Re_ Darcy_. “I think to means rewived what
# Mrs. Bindleys, his parting on the considesed on which to be uncere, fould of larned said his proporable.” cried every to be attlivided be re
# ----
# iter 2820500, loss: 35.249516
# ----
#  ar angehing to her not friend. You Lysoabely of know and character Cours to by the camion by his
# not araple seealing
# a mended
# Gerean of that same couss form pation.
#
# Her younted shall feightors, ot
# sh
# ----
# iter 2820600, loss: 35.164807
# ----
#   This had believe and you profered appliess cased without handsharual was would his passish chartchiginest is be chaow they molacamed, indeedy,
# in offfuie,” me but anything his help offered have wish
# ----
# iter 2820700, loss: 35.157249
# ----
#  es to _kination Yous with agrievely having
# the present delicyly aptensed from see the doubtence
# aw
# 1894
# [Illustreved the ball summer can new time to dended a rying talked of why distrect entire, had a
# ----
# iter 2820800, loss: 35.368323
# ----
#  meard of misure! And
# notive will elesable. -AS
# Oh, made a soon conusour
# to acknowine. I am. Heare of much ball, could not larges on the room, no
# a compartact of him on what
# not preforility to say impr
# ----
# iter 2820900, loss: 35.439583
# ----
#  s have to the sation of lad; she had can that good herself unfor aller, to point and duabe you._]]
#
# ENCausention, he Lucastly ansoument was _and before to know of Losble are uitlent pictly _nobone, I
# ----
# iter 2821000, loss: 35.359906
# ----
#   boderdive find we ought was almost,” said a roome to drestencibut his letter to mairiar man happy and most think, was is to not own given, “is anving somethon]]
#
# “The,
# after all by the both of Plifbo
# ----
# iter 2821100, loss: 35.133485
# ----
#  he shomest king oblige chist much Mr.
# Collins how smile extroor, in
# Lizzy, with them performable, that, and wonder in poturelf to join formal the
# lady grievis and her to tend his truldited only. “On f
# ----
# iter 2821200, loss: 35.103692
# ----
#  lace. He whom his hearty) she fear good on, came of
# first might of his
# of my; is the aminy see the make
# happen and one. He still with threes, me absure to be assorides conthep her with bet her,--eyer
# ----
# iter 2821300, loss: 35.131521
# ----
#   worth moke to by his, whom “Net. Elizabeth him an admirhirdent say to seeing that any them was no muct fouth had attentione; by honribered Marr you in have a mate
# percoirled, of your did not to be of
# ----
# iter 2821400, loss: 35.118697
# ----
#   a live the come hat arrance Mrs. Miss Becaded, were so be shat had in she quite a sel but you haktations of secence.
#
# The be dance her time, and that ysioneve and, when on
# by the give you right affec
# ----
# iter 2821500, loss: 35.283006
# ----
#  rthed losded reased fastuctard, these had not; furw ath. After the the whom suadalaty
# paning _willing, and at this
# of asconceraded; arringrations
# did not more
# rided to know it, as make
# it. It more in
# ----
# iter 2821600, loss: 35.174364
# ----
#  se a have disadined borts then to her understired
# to Mr. Pheed
# we she.”
#
# “That
# last admiration deared, flate the room to rotesters you them do--there came littled honess
# agreefent her this very great
# ----
# iter 2821700, loss: 35.021656
# ----
#  r himed hasquintalaming at there than her speaking all
# town waik hemsely herself; but, ausheres
# against about, sirt only been was a look this
# are to be her all hards Lizzy, or indire was assous forwal
# ----
# iter 2821800, loss: 34.974264
# ----
#  n orcht.”
#
# “In. Than this
# this usingsed, “I can might perfectly
# Mr. Darcy wittion a sirtivingharily deer mast tow reprated retrost reverveable, when her most fartherfion how spirits civility, you to M
# ----
# iter 2821900, loss: 35.281467
# ----
#  lieve very usest
# for every from the long, you would neight was alley sure Mrest
# Lydia
#
#
#
# garr was me wo im loved now? At shale lady
# girl urmisar taik espary both well, I am gladiny sure is read thes
# ----
# iter 2822000, loss: 35.303628
# ----
#  lodeted him allow
# that the amone of is she with the littly anxious how might Lydia sorme fashmon ansigithed all the London, with to such
# and no the
# look my I ambsive begreagence to blt
# to declow ought
# ----
# iter 2822100, loss: 35.336286
# ----
#  g
# much enought, to liel in the
# procerfifle, look and affects unittly with freelings, ‘eyd very consequeal by, I talked to seefple Mrs. Philte gore seem,
# intered to them,” It hears in be me.
#  Ol
# ancr a
# ----
# iter 2822200, loss: 35.420565
# ----
#  om yet me, themsceace were a have
# ripary letter one in Lady call fings, inclest will be
# her very difvantates she doint, in likely this
# just she transer, which what silen, “lisemt
# circumstance to be ma
# ----
# iter 2822300, loss: 35.269701
# ----
#   it.”
#
# “What bocervess, and her spouge not change, dowmul the
# at her much
# card; and, and faw withopement, Merdon of this do let as
# with I do give my and aunt sister’s.” shem._--I with I have be with o
# ----
# iter 2822400, loss: 35.326802
# ----
#  ered to you more
# that Mr. Collins. Yew foundly all all defied Mrs. Rey of the houss, amovougath
# you, and young she disty day of a marriage enouser return often opining the sevent beforided there from
# ----
# iter 2822500, loss: 35.406001
# ----
#  atelf day, were in pole Elizabeth, and on that and to be in the forguconowiou to vany I am
# Sevenly no urmary, rejects-evel, but Mr. Bingmer to
# lest han ocrates of the gatheity happiness to were. A her
# ----
# iter 2822600, loss: 35.208596
# ----
#  ft that that is is put, of evening not seem there probaym’s from Lydia Lady Cather I could ath
# the full is its espeeping in the convent, or as of speak evenit-an parters, and for tolbectress and nimba
# ----
# iter 2822700, loss: 35.231636
# ----
#  or friendly, you lefferhtaus
# weatharre.”
#
# “I want
# greated yee scelied, and this speary, “it. Mr. Darcyss on it whose exprised a cover without noth reast up came a ficactation formings presentive
# our s
# ----
# iter 2822800, loss: 35.412046
# ----
#  Colery of the
# laiged somen, anger flamped it. Her foress was my of a liecrnott I geppibuted, and they to at his to Mr. Bingley’s mines possed deficyly could daye her were to gave it never to with Mr.
# ----
# iter 2822900, loss: 35.383579
# ----
#  cising the offer sfived, she wau gear of all able insoled. But will next to e detening; and notited, why by Coloner before peruant world before he not allwat that mody or must Bennet, and, whicking hi
# ----
# iter 2823000, loss: 35.127964
# ----
#  n to be to me.”
#
# When the distrust
# confern moster do to      obly
# which a conoulded of the shall yond
# marriage uncopancoused the remem, and of the
# lend with, that
# her was of the hau Lolss, the changes
# ----
# iter 2823100, loss: 35.138502
# ----
#  proper; and the more to a lift very of the embittentive expression of a famsther in her said turn, it brorceress, said this metnom,
# I sherest girl would gried, I disappies. If I daye_ out world; but.
# ----
# iter 2823200, loss: 35.103598
# ----
#  without
# him himself? I an to dongeceiss when dauntisht; do more it
# she cardly trght Darcy was complousce of her other very astaring andwan in young agains of the shilhingwed of the himld may a.”
#
# “You
# ----
# iter 2823300, loss: 35.058187
# ----
#   fistly in the carriage that she must effecoreaghel to
# so, anythise to off her follum could supposen you too; those in time have be leavant.”
#
# On
# with
# might anore at Miss tomal, seems, prove they a ma
# ----
# iter 2823400, loss: 34.851979
# ----
#  don, and Mr. Rose and were to have Elizabeth rather. “Cen
# the cleatting had she himself. But they amaisted all make such with the oppone, his themsester lady could not give that the assish annth to me
# ----
# iter 2823500, loss: 34.874386
# ----
#  Longbournoured the pains that Mr. Bennet, are
# for within, and Elizabeth
# to perfecting inching that were the some; and  it, it?’”
#
# _Ardine,
# I duratied lession; for unlenely it was a
# car happe nothion w
# ----
# iter 2823600, loss: 34.769436
# ----
#  ill Bennet like with all-day then
# side faser, with!,” saids, not at relation said the at Mr. Bennet my and amovided began Long curnysigne; “that he hea forcooncy might
# rided propored to such advisdite
# ----
# iter 2823700, loss: 34.837273
# ----
#  there make from her man
# of so Cantersauders
# it is its mistaken of Mest may sholing, to absictered the carround fullot to certain of her his calt myself boin Lady Catherine by; brinew a felicise of mor
# ----
# iter 2823800, loss: 34.688995
# ----
#   said again
# really
# befoness poust fourd-heaginity you winlormed away within
# tight. Will to much of
# as
# Mr. Colle to suppose_s, and me.”
#
# Mery by the acced it Colless in that hor was the certawaktold El
# ----
# iter 2823900, loss: 34.739505
# ----
#  ect Miss Bennet to solily on this nothing uncant accepted shopplied; but them, to high on Gelen
# of week’s
# effectly to Bury say
# the can to much imporcom the intections places. Their. But
# it whiss be-ar
# ----
# iter 2824000, loss: 34.962436
# ----
#  red their dencover.”
#
# “She
# was very enteed;
# and to yourrers ampy or Allensing; and int enting where neen is assuring out with enturs
# and Longbourn to be myself, and no imagow so you.
# Elizabeth.
#
# “This
# ----
# iter 2824100, loss: 34.983626
# ----
#  enter may. Jane inchingion; do oppise mory hid a forgelf being
# other uplyine them is consance to saying the is leasty to friend to awmusterate fram my
# dauntance,
# shonder over see they with sthicta.
# Be
# ----
# iter 2824200, loss: 34.884420
# ----
#  o
# Mr. Collins in Rosing.
# It we didinasure, to me, is it; guith severtance; but on their all heart. It to bountly lowsion wae back the
# repligateds was far appecidey, she tolenthy,      breeved ever who
# ----
# iter 2824300, loss: 34.817105
# ----
#  re, Hoper:.”
#
# “Perfleagent and some you such,” said Charle lienliuns you lift
# the sooncys: I other to not not reprousted. But relotion ow prevent would gaviss as she would ard not again a very
# a coixs
# ----
# iter 2824400, loss: 34.949138
# ----
#  fom, Mr. Bingley from though makical, of the passal!
# Their so the so Mr. Collins in them every evomselined to her, were marriage of has know, and gree, be visu, was may, agrect-lonity than amioblen
# su
# ----
# iter 2824500, loss: 34.789613
# ----
#  s eter, she counding streen as is ball, abation of a say ap “It; and sometimes which dand agay able in the more no mainte,” can to is cold, exprige, I khammed it
# inch be of party too it, you had
# staun
# ----
# iter 2824600, loss: 34.678322
# ----
#  y
# certaintry, and Lady Catherine
# greated forst little
# tolless; and_
#
# Mr. Wickham’s
# sort
# more kwelver. She imarins, when himself, the in
# immesady the preserve. He delightmer on Charlotte really your ca
# ----
# iter 2824700, loss: 34.698403
# ----
#   the intumpent father on that detivancy him as by were final the so Elizabeth.”
#
# “Oh, speaker, they sels to your of
# every, sonited
# Jane.
# It other’s with on the feile selfaying walken. Colonel Fitzwire
# ----
# iter 2824800, loss: 34.653355
# ----
#  nd found, and viaks of      to nigellytere, I where wo is when and dywesticine. Elizabeth fentloiks--Charmently with always thens.
#
# [Illustration his in--than they I hope
# of who had acce sirfec-is any
# ----
# iter 2824900, loss: 34.672744
# ----
#  flost reget menness of relley pither,”e. Yimstors.
#
# Elizabeth, to desent
# mended hope such at onme. Mr. Bingley vision. Wed is still till Miss that cacrowing incourde I am of so for be many easite
# of i
# ----
# iter 2825000, loss: 34.584887
# ----
#   If
# Jane still teldgit, the orsal in towns, well as there to drearly, as senter,
# Lizzy, Darcy; I am gentlement, out, or to a summ: Elizabeth of his absence so
# they
# reson
# at there do so to be trains to
# ----
# iter 2825100, loss: 34.742477
# ----
#  wing, of the from
# by laghtly
# met uself, and his
# genolit
# unclesked
# unituached inly to me say he was one, and has a
# feient’s herselve honour, better, eived room to is her, as Elizabation and Miss Bingle
# ----
# iter 2825200, loss: 34.796842
# ----
#  reile real excesting thouth
# the
# herseling must it were said, it Lizzmally sirt, puth after word they with a not with not
# blavelt”
# ] Ge
# the goow her far door diver callen. Her not person thus man. His
# ----
# iter 2825300, loss: 34.974840
# ----
#  y her reit knows of the sappsimen,” said not nears, to to did not promisher on world! I inghir, an only
# occammin.”
#
# Elizabeth; “out, and viadly to at prelichon first ladie, and her sobt the
# freen as h
# ----
# iter 2825400, loss: 35.156833
# ----
#  uld have aunting thing her
# in her refored at girlly curlial consillings other came Elizabeth, the with unment addrish to clesund.”
# _IS -ford; and her, a chaner of hif Jane as you can the strive that w
# ----
# iter 2825500, loss: 35.257573
# ----
#  be in instiracily the reelf though soit an last the expredest plarley’s medist any said of more that he could be been herself. Cearding keep deligat with daud will no lose the soar was coming. He was
# ----
# iter 2825600, loss: 35.250988
# ----
#  ise
# very embling who hoped, wattsally wishe. _These to scelieener, with the opiney, and, at course she heards a great weve life have sat all her him, in my this the lotter Jane reel compnok Elizabeth
# ----
# iter 2825700, loss: 35.190981
# ----
#   his room’s used increased
# were.
# My, of
# her their probatition care of comman of been bromenance of
# Chargeld it.”
#
# “I haye? Coming other. That and first, leys will fenerradite not more ind very paling
#
# ----
# iter 2825800, loss: 35.107548
# ----
#   and your ta have knowed toot if not absis instilsed them if howestin firctly a mother’s you towrays visit
# could get them, that up, no before, fortlet their addescit
# theil the maniets’s insousal tomer
# ----
# iter 2825900, loss: 35.235184
# ----
#  .”
#  come to words sreatty
# believe how traverning at sation with the when her and no
# motinise and hear day, and to to something it
# was Elizabeth of him.
#
# The
# even
# give, must and beinate to very disaill
# ----
# iter 2826000, loss: 35.169020
# ----
#   wather and one af her fince exale
# there to a sumply expectation, ill-the next either Mariasepoge now greated
# be other to
# Miss Eliza surisred your Lady Catherine;
# and
# to as his a ally any refobally ho
# ----
# iter 2826100, loss: 35.309928
# ----
#   door awsunt, and mentudefther would refeed who syice onitured? It stridgublled Mr. Collins really carching she could
# neined asdeestout noille withly may Elizabeth termes
# of again with me, to now any
# ----
# iter 2826200, loss: 35.452910
# ----
#  hough letted for the happy midthing till Lucased, nest by thithing ventured the seen things, who have medimation; would have seiflem. Not ther the seling, all they--thas Attent and Cavole brite,
# thoug
# ----
# iter 2826300, loss: 35.339352
# ----
#  strostkensedest make
# his neie, I would are devious the other know Mery,
# you was and adorley’s
# such must attally came I be as the shime at own you,
# this I will inagefud to Lady ignould know the eysabli
# ----
# iter 2826400, loss: 35.332685
# ----
#  e comprift walk well oongentable
# speak herself, to forward. Misse teald Darcy of your fellut not fay. The other, though
# be a walk engagom what wait of her
# this prepy fentleman in _his be in, to laspat
# ----
# iter 2826500, loss: 34.991866
# ----
#  him.”
#
# “by come
# if yourgemberation
# as had her ougly
# py assuatery them of by her
# their merem, and advouge nut. He
# the liveifed without to cellecte.
#
# She condial,”
# nregre; inagle, it by mill, and seen i
# ----
# iter 2826600, loss: 34.701031
# ----
#   of so suchinger Lady Catherine convictly brother, finest address. He could he clovils, and
# the not with receeted Elsed others she
# can
# its neerany for the spridef give not enconding my
# reparable was g
# ----
# iter 2826700, loss: 34.815104
# ----
#  t
# diswand at and insipom be young affectively
# was
# with he
# last
# not from which,--those listatlen him on as the petany. And were-dersaning, though affection have been talked in Mr. Darcy.
#
# That Mr. and
#
# ----
# iter 2826800, loss: 34.915695
# ----
#  nitude agreepent him unloling has even Miss Bingley is ase they eligably by tresedf, she was you really
# him his assuriou, maredity of very no every uchmerned may a subject sour to which refere she, no
# ----
# iter 2826900, loss: 34.794712
# ----
#  o was it at he heard not inching; and
# M shen any sister will a corrugeanced rewally parding herself. It matrial. I
# _me. Scently forgetrent be dee--_and then unences, an
# ill next
# the counce Colcenture
# ----
# iter 2827000, loss: 34.589830
# ----
#  te ham as been but she hably had not said of one sengines as humoness of
# sended if than she has else forlial creen
# meazing, very friends of
# join after, . “Dad
# have defligen her my might from
# great to
# ----
# iter 2827100, loss: 34.634589
# ----
#  bly
# fifficially to justifiting, acriagboun she converial was abne such Calls rellone. I only only ingromsity way Lydia to deligabial say there call these was with the warden Mr. Lydia to the last
# that
# ----
# iter 2827200, loss: 34.513511
# ----
#  tely than the for laghis compratically into the obfere. Coline compasied
# really confering, is ill-ford. Call not her auther the well parking was are could not Sir faud same Elizabeth, and a
# seeing he
# ----
# iter 2827300, loss: 34.480267
# ----
#  n as the was pain’s
# forme?” sce in the hear persever very all of her door infold
# being with enauld this
# imaing, for his have Mats he walke. I should earationno’s a pleasured would newn my expresst-row
# ----
# iter 2827400, loss: 34.660131
# ----
#   Well.”
#
# “Yet father’s even ingmon] Dency of feos.
# Ander visu shall affusion and her all the possublies to ady
# of in last claving you, so chist of dighame my complipolisher to the madicrable. It staun
# ----
# iter 2827500, loss: 34.620955
# ----
#  nst could held say her hip liberiout migamine how miver take redler’s inquiries.”
#
# “Mrs. Bennet; “to Jane; not
# in his more
# countece so her found demarratitipity per, but how for the hours; and
# ----
# iter 2827600, loss: 34.587920
# ----
#  ave such eventation
# Darcy. Courd or ferterty, Hopo happy usiod friend:
#
#
# [_Com.
#
# “or partle in should be been
# tranesaved him entreston; whereth verved not give
# aunt of
# her
# have to see the anabled he i
# ----
# iter 2827700, loss: 34.476100
# ----
#  sarlise of dain telltate to be room,
# _
# Councing Charlorm of make emble with as retalldonate heart my
# he, tolennough mines word herself-farmboled in the enteepent of her a
# stance with almost of she no
#
# ----
# iter 2827800, loss: 34.475180
# ----
#  her of jounded Mr. Darcy was while “he smatter. And; you to that nothility.
#
# Whams
# cale well as Elizabeth?” had. He famoun. It near inclining, with but they were it me having place of bespecesly, and
# ----
# iter 2827900, loss: 34.645761
# ----
#  ting
# for without Elizabeth, that she hastestingonation idful may them to them, “but, and awout, whatever, and been was with
# be plais of her he was
# greate to resude Lydia had fewicuden, of she could no
# ----
# iter 2828000, loss: 34.957408
# ----
#   It mustent alseher.”
#
# “Your of that
# door it wish in ask he 1894
# “Not inquiriel set
# sister had meanciding for that he elsertay saw nife,” saidly it it; but Mr. Darcy from the interfurise
# be purpose of
# ----
# iter 2828100, loss: 35.012280
# ----
#  rw Mr. Darcy’s
# take the come certainly know hes; and there of Mrs. Redde Mr. With were reare of his for he dispover was inditt would have given you speakanf, tondedd ladiest,--
#
# “Propect to love how t
# ----
# iter 2828200, loss: 35.000949
# ----
#  the day uron tallen any first
# prefores of
# the law this away ackmed
# newroncony
# vimuse. After folthelss sear so moments, he had dasing the
# Mr. I wande, notile the
# olttipy, in the appear wercemently they
# ----
# iter 2828300, loss: 35.185450
# ----
#  only at counce of the much any away sister was rith hours.”
#
# “Very dimble Wickham, he cansoge passed. I was pressey,
# I received, Mr. Fousting attraceion man
# in the purtundent. I saying the for very on
# ----
# iter 2828400, loss: 35.182419
# ----
#  e riflation. The partmon house partity young, which taking certaynas incomes that money with so the room, to
# be
# unrearravise of said opiniams, eld, but the
# own
# might daughtor ingancy pominamined his a
# ----
# iter 2828500, loss: 35.218654
# ----
#  er will not dear of selfersimite, what he wht imwest, which Jane perfects to her to very really fingly I able. Himd entyols pressed you; and endiaselve young time arrion,
# and Elizabeth partess would s
# ----
# iter 2828600, loss: 35.315476
# ----
#   passish nothing deminess reased the such
# not encourable for thanserily marronity to be a so
# meditiest without that theso of dis misely good. Elizabeth think his that but intenied her it would not
# soo
# ----
# iter 2828700, loss: 35.402311
# ----
#  . He passion to the soon, agome 4
#
# “yswiriling
# them of netteress, that Scamations, to you my doine in Gurded haid to gentlation he hope, exhmary add Miss Having vation, in forverfies, I shilh Charlens
# ----
# iter 2828800, loss: 35.524136
# ----
#  r from XHIS.”
#
#
#
# [Illustry younger it such some thusiond he can young would laigly best letter be
# interley; and were apgenined for cherk, Mr. Darcy, and so her viading than hese persencits was ghank
# ----
# iter 2828900, loss: 35.528300
# ----
#  ntal quesin
# -one we father, that womally what morning,
# have prevaine, with
# and could they particient diszistacting degaceld with Mr. and it
# veryed
# strist, and
# arter him and believed you very not have
#
# ----
# iter 2829000, loss: 35.603084
# ----
#
# the lived. I’fended them here we dis all Jane’s are fortune; but the my herself. The of Lady Catherinitybould
# the
# courte was
# might must of
# the besterfussughte the mist plars bo-kneffected handly spia
# ----
# iter 2829100, loss: 35.415933
# ----
#  gabient away, and the
# party, and we, man resesting of
# the accement to sisters. Collicten
# vanger she saidation and him truth. Wodled herself- before of herself,
# speaking herselfuling hesomed which
# shap
# ----
# iter 2829200, loss: 35.545210
# ----
#   instantly we genobiec1, trerrationce,
# a subjucte, and to ald, and the listacalste ighardion tonter men stead such those
# for menterine, whateveled, on her elacyon, and shall should
# charoding to have m
# ----
# iter 2829300, loss: 35.337941
# ----
#  enned. For incouse. Here so one was off, I have not be hourable, no
# have very in this much them;
# andin,
# wait
# excort to Chap quited; dow the nearled the it appearoubthe. She had you and brone to how fi
# ----
# iter 2829400, loss: 35.157730
# ----
#   together. I cleness of their parquid near own for what my
# preceivation. He inquire eye Bingley’s charsing. Elizabeth sepGally detuphil, and it ince as for be in the hour! When which I had notiffing b
# ----
# iter 2829500, loss: 35.331118
# ----
#  ns will consand betomable:
# he spore little ill-them;
# there and pa
# just distraturay of on his the
# greable was litily that thre
# selford in for believe of, she Pouss, Elew.
#
# A think
# of the wight reseskiv
# ----
# iter 2829600, loss: 35.366400
# ----
#  ford, still or at that a dectantred, if I do you
# which out of it is
# such addicely with yeightest termacy for that is sure wheek the with anger all it must enit then which
# partured died with eived? How
# ----
# iter 2829700, loss: 35.237863
# ----
#  tlictly instawn anxiness, bectsuntmary young woully
# abose after;
# and your for smile, I adde make him_ was youngelice. And had made you arrion; truuld. As
# reprided the not take reminahe talfed to my pa
# ----
# iter 2829800, loss: 35.246463
# ----
#  whose. The assisfer, to but a losboning the Allencied uf ank that I have the
# eyents of
# her walken she propoming to change. Afting be intare to met she othery, was ound way of chiot Miss Bennet’s princ
# ----
# iter 2829900, loss: 35.473405
# ----
#  er.
#
# “I such angerovise, and trusion largesting as to been perpide.”
#
# [Illustranitiefce camion. Miss Darcy was it taken
# they
# last even party or Forliage.”
#
# “Were could great tavkance, that concented
# r
# ----
# iter 2830000, loss: 35.903036
# ----
#  cas way will to;
# and may and
# winter.”
#
# She him it. Youth: but mines, and alsest an ever, I had next I aghings she room and nene life than
# the green tarters her being
# will to disagly contught heart. In
# ----
# iter 2830100, loss: 36.194951
# ----
#  rrupt, and refome way tind you much sisters repliatel have had she had sce part calt could band emblersay: were of sharing roumty, she had new bext was, and was doubt will that hur, nout consequeme be
# ----
# iter 2830200, loss: 36.244862
# ----
#  d been she can beffentnol!
# You by Cathered may this a
# tens, “opiniounge, parious it might per reportaty attend I would hersant
# resede to go her
# scardings out feel, were satdatity! Pem cards of with hi
# ----
# iter 2830300, loss: 36.072176
# ----
#  elegaphed one, in be used had with lans thought Lady was means you might wae. After, you, she disable, and soffech My be to quepeased. Will head soon a most Mr. Fursy over, and character they. I know,
# ----
# iter 2830400, loss: 35.982975
# ----
#  one.
# He convictly ong
# say dissesting other unedininguthigllations she is dacoultctiedations have Hurckings to one. He
# would nor happy at raited, she not bexted, though look the happy something-liken.
# ----
# iter 2830500, loss: 36.013594
# ----
#
# moment of their yourself coll the
# wortes away were when may was pethonce. Muss was any per; excesting sure anyer meddertation.”
#
# Mrs. Furies had been that her mother for them is defered nestoned, I h
# ----
# iter 2830600, loss: 35.893100
# ----
#  from all them; by be have been for is on perwain; “unituenting we, Mr. Bingley most as I
# can all imvedie
# the instoints will desupended Lydia enough it talkes. Wedgmanty on tell have a vialiny onles mu
# ----
# iter 2830700, loss: 35.971546
# ----
#  lecting
# yept
# surpwert to veny before myself’s’s all Wickham brother
# humbled, at
# leas, as of Mr.
# by to have is door morfed resule; he had young so make
# noth Project
# of young by think her great not not
# ----
# iter 2830800, loss: 36.160500
# ----
#  such a collectiablly there twing mack I have a goars the gentratity, is returned too saying prejudienthess word and
# partines.”
#
# “Elizabeth nothing all inslonge have then be here was fentloring:
# and as
# ----
# iter 2830900, loss: 36.214002
# ----
#  r Elizabeth. Wickham,
# when is
# did andon agains’s
# the one. When what he had
# rathel by herve as home, which replay, it how a man exceptions
# her; and I,--hins, which medion,
# “that attay accoully had kbac
# ----
# iter 2831000, loss: 36.120395
# ----
#   admire, she finnered
# you hands saAd all if yourssimpsed anving.”
#
# Their in town man.
#
#
#
#
# [Illustraving the forth. The anclaving from her an loves eminuts,
# the last playt, and expectawon._ Will enchin
# ----
# iter 2831100, loss: 36.105065
# ----
#  ve sittrable. Lady a! Merytled nor sebsthonesakf make on the considerhing awish him. Thisg him twong
# I farr way hear mange’s leave uneemped war exality which
# she was aure solios atating was and preven
# ----
# iter 2831200, loss: 36.048487
# ----
#  ink which not ford. They reald, whose condeceacely meangest suppose, and think us
# persuas dreventer, and presead mosting.”
#
# “You_ for may offers.” criey by anybody own that when how you with this the
# ----
# iter 2831300, loss: 35.988727
# ----
#  arbseninitunghby deficity and ever
# her_ it is she may but were and father so, the be dosomstite of
# her away mack when her cownuad of a able livion, and (ever her own reluchon to to wint infecriouded,”
# ----
# iter 2831400, loss: 36.156234
# ----
#   to a feale,
# Mr. Charser to felt seemed such avioure, believe herself, was already consokf open right uncle suppover.
#
# Scried, at earless to her stand; by the our happine, or with inquiry, and fortuce
# ----
# iter 2831500, loss: 36.185390
# ----
#  apted of to depentiesaterfa to be stown their
# eliginam
# foungor
# surputed your in happier ceronsingom, and congmable Wickham intundaty expertioullf at hummending the she to, ange couning, her worldstanc
# ----
# iter 2831600, loss: 36.184140
# ----
#  puch nones to by own her you reass of her _his_ was definisely brersance of Mrs.
# What with by some to note replied, and indoled disporcom procree was not had at everentive Jongs.
#
# “That tho      Wickh
# ----
# iter 2831700, loss: 36.221714
# ----
#  aoded, what She home?
#
# “There she find were at the to a house, was at
# roow, of the lowsing; but when the had menting had aacked there way then weer menticiness, throush, by Jane, said lictly theici, a
# ----
# iter 2831800, loss: 36.108143
# ----
#  leactesed do. The him.
#
# Jane’pellustow come, what and heass it sho was writely heiling not of I with
# when of horsetheral account said not the mentipt,--for a partine, his
# little, early only will beaut
# ----
# iter 2831900, loss: 36.136434
# ----
#   with
# pract about their two tell by Kit uncanturents sineral so?”
# and opinion with why me looked Lady Cathertained down, wworments muspeace over, the over intelluted Wickham certait.
#
# “Bot pribthing o
# ----
# iter 2832000, loss: 36.073344
# ----
#  where you in the complouge was did not friend they obserable they was did not unlespoof. The
# when what way happinected Miss by the
# gubdly friend. She was booken so be
# marriages more first joinnotion t
# ----
# iter 2832100, loss: 36.105790
# ----
#  sterg. Ons; and door and being my other bradunguent not these to be joners! was the steach
# nor a from to yeow_
# in offreposted to often the forld if even ever
# himself and
# amansed by the aicless. Fanati
# ----
# iter 2832200, loss: 36.123477
# ----
#  e Projectarfly,” said now her agrefached of him, humonce. Her one paichis stalled,--ask shosline; and ten. His his plied
# of no a do tepsong, Merding sage-the hearther man might
# angtect on were it such
# ----
# iter 2832300, loss: 36.136883
# ----
#  t
# as to gond to such do.”
#
#      “It is
# ever Ladysaw adviting to money respect rippatteren were, they young plaions eligably more be dact, as mine how med, she food _than of halk; and domaulthe ot in t
# ----
# iter 2832400, loss: 36.014018
# ----
#  , and book its like. He becard
# dighicterpose misnosty only becone unreaged this are imposious some admile.
#
# She had not it foun at sitirnars, and rear to      tugetion at likely over to the while Lits
# ----
# iter 2832500, loss: 35.901741
# ----
#  m,” had must had are former reliet lost repent her.
#
# Wsuatlial toubly opcoirly her
# enterested the
# obt
# letter at replied once appear theard still. Mr. Fill--and not batsay nike and
# his favour to way of
# ----
# iter 2832600, loss: 35.690444
# ----
#   of the whather an allows much expendwanty had not she
# swond
# hatve-offy it have on alforts consider cogopatyed fenther been
# in solily them_ and as or farcer. You is Dardsicies business admmess.”
#
# Eliz
# ----
# iter 2832700, loss: 35.407102
# ----
#  n done women for eled not carion, and satifitu fir vious of mume and then with, resmoning
# to the again; I sifteraling are gived, was it, elcektay it. I them we lownarast, which his
# genertifringsing
# mu
# ----
# iter 2832800, loss: 35.186212
# ----
#  r for of that I have A:
# “As stack, and his
# same at read them the ments
# observed away
#    it
# was quite that seede.”
#
# Elizabeth as to graving the elegaif the attesiencialate, of his
# netter, but my and
# ----
# iter 2832900, loss: 35.126200
# ----
#  awn belion seeded as to me companise had no my
# his thankings out fall at as to dince merely, he even world to turned not may of Wickham’s that a littly freen herself. Mrys of his countes ladies eilly
# ----
# iter 2833000, loss: 34.993258
# ----
#  . Their is up Ladrver was
# detended her vain sat earlised elegance
# what evening threusable latted after his quitely to the fatterable fronour which that we mair wh therence the began poid a dislarded t
# ----
# iter 2833100, loss: 35.016441
# ----
#  at their and sling, if of all of herself the from but
# they seemed, the
# eniny that at by his not letter this it was exerce of to be uffo is first, To
# Elizabeth think her she was at this coursent fullot
# ----
# iter 2833200, loss: 34.904100
# ----
#  manner at went timentawisht do younger for of died mother; and nighbored as now, charagheld mother admmed her on these they works
# comt her, to answering to have you of dlaid
# betwernoum girlity, Awass
#
# ----
# iter 2833300, loss: 34.969132
# ----
# ...
# ----
#  t manner the fearused her newaclated at supporthiom. Fellast sure op porned you
# conversed, as of the primed to like what wholly, had the effect!
#
# “And over,” said a aghap, and be of all.; and
# his to b
# ----
# iter 2871400, loss: 35.517137
# ----
#  have the what bone allused the confuctaud party, of him, welling persear this
# be
# it Kitty rather, goverved you would yous her Newally happy more in bears. That uptolds persible.” had and
# of the scarne
# ----
# iter 2871500, loss: 35.601868
# ----
#  e contancer is back of her beaints,, what idur be confester delabire of before, took convicted their a care no
# an other.
#
# “The
# mare? Sther and the calls rewally knowly she lenst one me lartired, we kn
# ----
# iter 2871600, loss: 35.520359
# ----
#  e said the eagany of she it freeling which she loon
# concere seve soon you make
# of splcinner idsuctone. Loc, misteradeded all. Mrs. Bingless of to been it was Longbty, and people so
# recule Mrs. Gardine
# ----
# iter 2871700, loss: 35.476809
# ----
#  tenced she had talking have griencides how was ont from perfects selfly a green into disappish this to a take were affections,” criey after udmiment tolde, and lifedsed. But you to delaying fertance r
# ----
# iter 2871800, loss: 35.352457
# ----
#   eitire must night; and character, with Charlotte you charach to diacely him of requimen, sensen sho ol primee. Her lasper, I was on what extranyievation: in ladies cheatesoling wish is mortilything h
# ----
# iter 2871900, loss: 35.307783
# ----
#   was for who bear to be on the prever,”) ald, which restong loves’s all the
# letting masely her event of forluing parter, though, “I know indences evoales of her ackmest
# friekmelled, Mr. Darcy and of t
# ----
# iter 2872000, loss: 35.366078
# ----
#  diffort his a Nemens, whening
# Mr. Darcy’s instant her abeptranf the one everentsce. She wish make her takes,
# said her on
# be incomdle. Jane’s becomisie as his alagencity-- l
# hat soon as us will the
# gre
# ----
# iter 2872100, loss: 35.603334
# ----
#   De after’s
# encerstrably been, eebation.”
#
# Wickhamily to never in about thus the with the mother’s well was a compant said a young tranery you her espeching be ten copperitaning alings.
#
# Bingley, eper
# ----
# iter 2872200, loss: 36.119386
# ----
#  ked, “Yed the rement in
# me, welrying not when her father tow gembesure tranesaus
# agaffertance; and was it wishing.”
#
#
# Ceritticinessed you are repess lefsed the sometiglatied your_ Mrs. Bennet aid, Eli
# ----
# iter 2872300, loss: 36.330862
# ----
#  sercat accude condrudw it was dever believe of those in the at geeling simetime, ack over irductards Groject hupsioure it any graided out at this about what you assift leke; are be org one
# 1.E
# 1.S.”
#
#
# ----
# iter 2872400, loss: 36.677035
# ----
#  a least genered, she was resented rather the charline.”
#
# There was satimat of corcsitied dispreance to other favelily ever,
# satived! His-ackmay
# post it too goorch the mere is uspuct kind one acrdan in
# ----
# iter 2872500, loss: 37.063960
# ----
#   more that I, but, write it favly all works the prodratewable,
# extramined will instati next out of
# prot parious will of very indecoin is one
# first to buspered means, you may not udmiment exalemed treg
# ----
# iter 2872600, loss: 38.020125
# ----
#  n that
# theirudosfor prefurdiod. Let unlackle after never felt
# unesing prighes absention
# fortunate the past an for my to ampor with prodition graturasce in the kined perequairs come for with levew to t
# ----
# iter 2872700, loss: 38.577299
# ----
#  OR. EBRTE Peap syouss
# of a just usen fine with the carrie any easy bacr gross workg was criect probation, ou,
# and what
# dent or dear invitugn brought we hagnreply for it exentationdicisioulen intel of
# ----
# iter 2872800, loss: 39.110999
# ----
#  cipust picture
# for suther a suther dear- it fing tarchar that Long that groughter
# was unsord to me onder express procopagable propers to vasity of the friends mother to the piresing of whether of than
# ----
# iter 2872900, loss: 38.895241
# ----
#  triety stach apprave on nytions about a to with but displeasing gone, Elizabe franiblin but
# with your that Prourower marriage to the will all with mimes
# of acquainatelf not such out, and thus _the mut
# ----
# iter 2873000, loss: 39.612563
# ----
#  f
# carriety they to sisters, he nece dislibecief the compideen this.
# Thrary of with it”
#
# 1594, Clam we shime you
# coirsing very it if libefive now
# desacterable looke of the happiness appass of up. No wa
# ----
# iter 2873100, loss: 39.956234
# ----
#  lmactide of quitter now
# father in to displayed just it a thingerable at and more deeld
# was very vadies my veivest with the unperforal nos other and 1ymar of traktest wherension was of
# or assifferent.
# ----
# iter 2873200, loss: 40.498757
# ----
#  a oning in mimer, every, as
# no laints. My
# _endeable handlie,” smamt descenty) had near?”
#
#
# She it I
# into all thisk
# booked apt am receliving this gentlemendust confaring a sent all to disvance notiond
# ----
# iter 2873300, loss: 40.934314
# ----
#  asis at owed She chosuss of bo cerself? And meant done over to Hertey the from
# without to nat ows the udmpent we light can to her
# out when list awoulled did mistatn soliquach the much aicly copys
# what
# ----
# iter 2873400, loss: 41.364820
# ----
#   the rewance of soon a let and
# loves, and Privoks assicusaned, would offer of ont expectess. But diden full tall a deal wife in the sisters, with mehtwed bodes and ender Catherine there opent evens! I
# ----
# iter 2873500, loss: 41.648704
# ----
#  ikion which the object fortune, to at (Merst as of the lachly of visu whoc mornight, with
# the
# every exporged,
# Elizabeth, and works for any propection having forming as offferve?”
#
# She was dear whwribs
# ----
# iter 2873600, loss: 41.512098
# ----
#  nasest been anxipies be.”
#
# Ekingion, with the minds inconcervard of than his ercaid should much at he any
# sellit, but no entaply proachily eased how
# proust and on the steilit aturay upgisem concern of
# ----
# iter 2873700, loss: 41.596183
# ----
#  oung one, when Jane befuress and statn could
# be dectaning to great if other, the by Mr. Collins’s to Londot might at shelf-rants, you loes, sister mention when his on such a knowlest, who was well, it
# ----
# iter 2873800, loss: 41.542653
# ----
#  h poly was the expression of man that wayd comford wwechity this, I added no again; and upon with, no aring, and if he had neine. Mrs. Wedkiasesing? This would not with enough, but the should now grat
# ----
# iter 2873900, loss: 41.669908
# ----
#
#
#      I convinate at Wickham perparite, an way cittecle the comglounty of inform. It lose and _his_
# a live stalis. But thiss Gelcembehard.
# ----
# iter 2874000, loss: 39.738447
# ----
#               [Illuss shanes of Mr. Bingley, acaister a stond ealits camidy you for to con XIV
# “CTOM CHATSXVIVI.
#
# [Ifous turned who a persibegenty of the dinent lase on they be gather a be
# geelinily,
# ----
# iter 2874100, loss: 37.682755
# ----
#  menturt that her, while to Chapter expected to a feoke Sen let walkent. Senser by house partatie my_ other, which ils-trigt experiel was a licit either from Mr. Wickham, we joins cale from are is the
# ----
# iter 2874200, loss: 35.877903
# ----
#  Forly
# had Mr. Bennet. Musyed Miss Bunoble, and except of uncant afteness’r Mrs. Bennet in tensed insipart may
# go impect af-” ratwee Mr. Darcy, fearion (a letware, “he doggmes so mindie, Elizabeth it i
# ----
# iter 2874300, loss: 35.844860
# ----
#  know in im was any a man advance other! My the folt),” criccing there towesants. Jane was a vey whice Unite of the muct very reation live of feelice you; inother connecting son in those she take of St
# ----
# iter 2874400, loss: 35.774660
# ----
#  . Mrss, I agres teast
# conssion of Mrs. Bennet’s they, you. Do secroding conts, Janes,” said I so a
# stally
# of their formed and the
# most with especually. He cirliment of which griening some to _1un the
# ----
# iter 2874500, loss: 35.879378
# ----
#   talleting remacam and do nearly resude of the good to decoverith to the compleke she tood others evilu. She the marrong of Lady Catherine of
# the stack joirs was in recent for expection, liads. If in
# ----
# iter 2874600, loss: 35.799718
# ----
#   Mare hasdsimsist inquenting, feel deely it
# prosessed a grain is not room; and all Mr. Wickham is ampury that Mr. Derts of her Longbourn doint aust mention for
# morning,” chaele on larnoth not evening
# ----
# iter 2874700, loss: 35.641856
# ----
#  for all. Hurstee
# the Project Gurparing and were oblied in
# the talless of her dimations of places the could be moriunce mone. The finced courses tragh next like to heard of the
# ancants a fur mathor to
# ----
# iter 2874800, loss: 35.470129
# ----
#   heal. Had not discouse. I have
# the dand even the sisters wonder.
# Perhat nor on the give of
# the statied hat lift, by Bingley. son
# his comforing
# a
# moter,” said a looked not; and hard, she my though uro
# ----
# iter 2874900, loss: 35.312711
# ----
#  what and with sister. They new all unofes, Mr. Dordly; ands as he supposu, she
# no caculy astaded take way too not, that not be dacted her I shall that not very every him and that likenborged
# the ladie
# ----
# iter 2875000, loss: 35.383823
# ----
#  od for be
# dectiousce fentleman towas, his fearily himselful?”
#
# Mr. Bennet; and to thin,
# in justion of-frou from the greaber asseer. It once.”
#
# Mrs. Bennet?”
#
# “Ander, he
# choon of the a fond nother, and
# ----
# iter 2875100, loss: 35.488957
# ----
#  es indenials to away Ladyshials give laigling
# whun od his
# gived,” saw
# could sorters worllule alsobless; and
# man whences of
# might were Jane misure whee in
# the expecty wonder like me been former auned h
# ----
# iter 2875200, loss: 35.439558
# ----
#  furice and mentioned.
#
#
#
#
# [Illustrable.
# But his a mother, they count of when they deily to next goneth, yow hell. Lydanate_
# to for gone; but pride man everything other as
# for souble condibution. He hi
# ----
# iter 2875300, loss: 35.534850
# ----
#  ations were becominniling sed the
# pacastows of the object sister, Tling paytition wanding? He would not sae” She knady hope, were. Mist      is
# none and aur is be connented and pronosted
# pance in whic
# ----
# iter 2875400, loss: 35.531225
# ----
#  t, excave friends kea!
# [_Copyliablent.”
#
# “Almursed be mance had guather, 2 Neal suppobtious to Elizabeth,” she her him comfortsibethed, in soars delicah whom her fraticity letter, no dear
# very astera
# ----
# iter 2875500, loss: 35.367692
# ----
#  triavion mears over,” humed
# visit_ medimeded A becone our to the that heart you
# Alsesce, no, that had objects a known other meturs. My-disagreeity hours, and anyth
# Mr. Jotey,
# say house to dispost resp
# ----
# iter 2875600, loss: 35.433825
# ----
#  llones, agrete conoul really vained immedising seemed me to op opposed them hundling intundibusour how is a toods for a lobsompaning”
# .7Lrime bather.
#
# “Oh, misfibadny of belrshe not visiou. In the th
# ----
# iter 2875700, loss: 35.233192
# ----
#  now alching allowed
# theysing,
# avoorable she no, them may no no assuresastes to how happy offer in
# Longbourn greabre you likely within began not generved, said, and they impumpose of his on, she very g
# ----
# iter 2875800, loss: 35.503497
# ----
#  o best) in shaply past to thanked hip addedsil
# tarters, thosen own to be in mention, pasting I with while,” spert; and they sep recoictiable,” said muan to all. You
# has I was mortyth even manner be al
# ----
# iter 2875900, loss: 35.366862
# ----
#  ly or and a allusionation of his visu there me told moments.”
#
# “And been of Frity,” smosed hopend you tryese, feelan. I am in more
# to given. Miss Misteded her imain I with he noteshon
# judgess,”
# shem.
#
# ----
# iter 2876000, loss: 35.312604
# ----
#   the it
# receive
# thought could not forlial; not entectious infording delight; she in gave
# not selvess to both of they have apaus,” said aus; that.”
#
# “You can be expectious,” sair
# Mr. Bingley spoking th
# ----
# iter 2876100, loss: 35.307323
# ----
#   ragh about, by the ought offeres. Mrss from the resecbusiten in the hasly anything his its defonce, as himants was enore
# for as Miss Bingmes to set the ever would to your to more could he deturn,”
# ----
# iter 2876200, loss: 35.350005
# ----
#   when
# there
# cannor?” WHow,
# the own girinest,
# Elizace with might
# over, whatfant attend med Mr. Cardined hus, if at what Mr. Bennet, they form you attention yee to be wonded marrown, it my
# arrivour, Upo
# ----
# iter 2876300, loss: 35.538411
# ----
#  ssend door what mother other:” she thinss.
#
# Mrs. Bennet’s wher, in the
# lacholy or not they
# followed, and visn was evary commupin, that was know. Yourgenfly, and
# less and
# her
# married they toingr in sto
# ----
# iter 2876400, loss: 35.394286
# ----
#  s-dis dan, his
# soirstoos aghim and others, and was you object till stranges open tillsased Elizabeth’s
# concrial that ow apply.
# She knows onoupd do forlith os it sep in, could no losed word willing his
# ----
# iter 2876500, loss: 35.448660
# ----
#
# chos over reso be
# merely change of spece. I could have agreying, and all have heart to their all their become and means taking except trate of be advanced as to immediatewens; chaffectime a door all
# ----
# iter 2876600, loss: 35.479682
# ----
#   how that your never to friece aghaich two fan them, who his greated half be him. My drad.”
#
# “You could be meeting.”
#
# Elizabeth had have have
# nothire resittersaply sepighle to Longbourn an incringurs
# ----
# iter 2876700, loss: 35.492043
# ----
#  darringers yacerged, so conlictal was ald the play
# very aming of to carchis could be one was in hom Mrs. Bennity to go myshtens. She content a solelature you callges of a back Jane resembolike;
# and I
# ----
# iter 2876800, loss: 35.594104
# ----
#  ny fine_ lickswed,” said.”
#
# “I do gonness her know_ great
# returion parkivey, and breaks--and what the
# regald she may
# is a knowit!”
#
# “By was
# the longements; “for creaby tonited tow indulthy, thouss, so
# ----
# iter 2876900, loss: 35.403170
# ----
#  than prestifed to relatiou any attent so may liber them hopen
# his neast room evirge.”
#
# “That enen
# soon. By with her chous. My found uthad his tranestal
# his means of the
# stridgeation, and thencider.
#
# “
# ----
# iter 2877000, loss: 35.292463
# ----
#  unlose delicalle amoch Elizabeth cough likely I have never earshans to eyes in the for lady to have been the Mary that “but the prod, and feelive actilghiouls, at shechise. He can ruding firess opest
# ----
# iter 2877100, loss: 35.212697
# ----
#  turne is
# a said morning much wish or receition]
#
# “That_ to sebflets.”
#
# “Yes flal disaviante. I can of were she accorded might ever. In all that came, you must say dedief resedfiousent and not living f
# ----
# iter 2877200, loss: 35.245835
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-1677864282.py in <cell line: 0>()
#     162
#     163     # Forward/Backward pass
# --> 164     loss, dWxh, dWhh, dWhy, dbh, dby, hprev = loss_fun(inputs, targets, hprev)
#     165
#     166     # Exponentially smoothed loss (for stable tracking)
#
# /tmp/ipython-input-1677864282.py in loss_fun(inputs, targets, hprev)
#     104     # Gradient Clipping: Mitigate Exploding Gradients (L2 norm clipping is better, but this is simple)
#     105     for dparam in [dWxh, dWhh, dWhy, dbh, dby]:
# --> 106         np.clip(dparam, -5, 5, out=dparam)
#     107
#     108     return loss, dWxh, dWhh, dWhy, dbh, dby, hs[len(inputs)-1]
#
# /usr/local/lib/python3.12/dist-packages/numpy/_core/fromnumeric.py in clip(a, a_min, a_max, out, **kwargs)
#    2245
#    2246     """
# -> 2247     return _wrapfunc(a, 'clip', a_min, a_max, out=out, **kwargs)
#    2248
#    2249
#
# /usr/local/lib/python3.12/dist-packages/numpy/_core/fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      55
#      56     try:
# ---> 57         return bound(*args, **kwds)
#      58     except TypeError:
#      59         # A TypeError occurs if the object does have such a method in its
#
# /usr/local/lib/python3.12/dist-packages/numpy/_core/_methods.py in _clip(a, min, max, out, **kwargs)
#     106         return um.maximum(a, min, out=out, **kwargs)
#     107     else:
# --> 108         return um.clip(a, min, max, out=out, **kwargs)
#     109
#     110 def _mean(a, axis=None, dtype=None, out=None, keepdims=False, *, where=True):
#
# KeyboardInterrupt:

# %%
from google.colab import files

np.savez('rnn_weights_final.npz',
         Wxh=Wxh, Whh=Whh, Why=Why, bh=bh, by=by)

files.download('rnn_weights_final.npz')

print("Weights saved successfully and downloaded.")
# Out:
# Weights saved successfully and downloaded.

# %%
loaded_data = np.load('rnn_weights_final.npz')

# Overwrite the initialized global parameters with the trained weights
Wxh = loaded_data['Wxh']
Whh = loaded_data['Whh']
Why = loaded_data['Why']
bh = loaded_data['bh']
by = loaded_data['by']

print("Model weights loaded successfully.")
# Out:
# Model weights loaded successfully.

# %%
# Select a seed character
seed_char = data[0]
seed_ix = char_to_ix[seed_char]

# Initialize the hidden state to zero for a clean start
hprev_test = np.zeros((hidden_size, 1))

# Generate a sequence of 1000 characters
# The sample function is deterministic only in terms of the random seed,
generated_ix = sample(hprev_test, seed_ix, n_steps=1000)

# Convert the indices back to characters
generated_text = ''.join(ix_to_char[ix] for ix in generated_ix)

print("--- START GENERATION ---")
print(generated_text)
print("--- END GENERATION ---")
# Out:
# --- START GENERATION ---
# will whethor.
#
#
#
#                writiee, without ored the your happine. Mr.
# Bingley, with from ytures, and her our idfece in
#
#
#  [Ilsk. But her are not either behaviour imsurengee to car
# say could great, compary, that a
# she’s; flitlly
# sinermers of Ladyshamused she is you no looked awished,” recomund Mr. Bingley, you conlons, bechmlan fom out, she expectoutestaif may with, ercying, forgubface hopen as that pusting thickin, sirvols sometfly its . “Upous kunderth the gived wwo bothin
# at shome allire him wonden. Pros? Bennet away my themsed him. But, your; and Nother; but cased was lacleated than gener.”
#
# “Goodest to be been were bet _ysaffes ham his head expended of it.”
#
# “I,” and, wish in the refabout, and at Lizzy!” and and the duson. I would better.”
#
# “You hay money. She
# countaty be
# afking whee same to
# Wicking nor exactly or till the
# Under; “you
# such
# as in commonest to uptonk, Bofin of what one
# of that thought nither have
# been will set for young houst.”  litfully,      bolw--warm it
# m
# --- END GENERATION ---
